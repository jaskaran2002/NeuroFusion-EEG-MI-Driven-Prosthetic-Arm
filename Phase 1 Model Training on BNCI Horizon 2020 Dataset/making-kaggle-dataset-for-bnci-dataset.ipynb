# %%
# !pip install gdown --quiet
import gdown
gdown.download_folder('https://drive.google.com/drive/u/1/folders/1LF7Vsp5H57BcL5nB29OepTYqaFU3ABgj')
# Out:
# Retrieving folder contents
# Processing file 1DrRCytaDs_o0rnARG54zroks6zWhPWu3 S01_ME.zip
# Processing file 1AHvT2XK8cA0dDf8ulKXmXxnxL-lz3b9c S01_MI.zip
# Processing file 1q2mLiSHHDjaJNTUMbPoFucgIixP2CPoM S02_ME.zip
# Processing file 1yLE8-2KibpEEMvcbKK5f8bxwEtgG2CK2 S02_MI.zip
# Processing file 1hnLj1v3w-52tCl9PoGDLYMgy_7teIrFh S03_ME.zip
# Processing file 1jm9yxCSDopyU2Jksbr3Hj8cbtd38nba0 S03_MI.zip
# Processing file 1qIAFIoGLWARTvgC79mbEqDQtismFlZQw S04_ME.zip
# Processing file 1tW4sKPA6YNbszmIItkQslPYv-vVDoGi0 S04_MI.zip
# Processing file 1VtDsEecJPqihZStaclTXRnsHzfxhH0pQ S05_ME.zip
# Processing file 1KQ95DWGuNYAma8KX7-PhCi0EHl0DK4Eu S05_MI.zip
# Processing file 1OHm2I-u0FMzbi3Jg0Nhzx7l_aZDmdLKo S06_ME.zip
# Processing file 12YqWjQx2QeiVZqXC5sKMWSwmFj8X5-CC S06_MI.zip
# Processing file 1-2YZ9FOzmdUYaiSfNivgN-ov0ORZ9ldw S07_ME.zip
# Processing file 134Ji-ZsWsXvH_TS8HL7YPz42kt9eXzNs S07_MI.zip
# Processing file 1Gi0SrQc9g-wJeEYHIT2Kft3mflNVxOqh S08_ME.zip
# ...

# %%
# !zip -r bnciDataset.zip /kaggle/working/Datasets
# Out:
#   adding: kaggle/working/Datasets/ (stored 0%)
#   adding: kaggle/working/Datasets/S14_MI.zip (stored 0%)
#   adding: kaggle/working/Datasets/S14_ME.zip (stored 0%)
#   adding: kaggle/working/Datasets/S12_MI.zip (stored 0%)
#   adding: kaggle/working/Datasets/S09_ME.zip (stored 0%)
#   adding: kaggle/working/Datasets/S09_MI.zip (stored 0%)
#   adding: kaggle/working/Datasets/S02_MI.zip (stored 0%)
#   adding: kaggle/working/Datasets/S06_MI.zip (stored 0%)
#   adding: kaggle/working/Datasets/S15_ME.zip (stored 0%)
#   adding: kaggle/working/Datasets/S11_ME.zip (stored 0%)
#   adding: kaggle/working/Datasets/S01_ME.zip (stored 0%)
#   adding: kaggle/working/Datasets/S07_ME.zip (stored 0%)
#   adding: kaggle/working/Datasets/S07_MI.zip (stored 0%)
#   adding: kaggle/working/Datasets/S04_ME.zip (stored 0%)
#   adding: kaggle/working/Datasets/S12_ME.zip (stored 0%)
#   adding: kaggle/working/Datasets/S15_MI.zip (stored 0%)
#   adding: kaggle/working/Datasets/S08_MI.zip (stored 0%)
# ...

# %%
import os
import json

from kaggle_secrets import UserSecretsClient

# %%
secrets = UserSecretsClient()

os.environ['KAGGLE_USERNAME'] = secrets.get_secret("KAGGLE_USERNAME")
os.environ['KAGGLE_KEY'] = secrets.get_secret("KAGGLE_KEY")

# %%
meta = dict(
    id="jaskaransingh2002/bnci2020",
    title="My brand new dataset",
    isPrivate=True,
    licenses=[dict(name="other")]
)

with open('/kaggle/working/Datasets/dataset-metadata.json', 'w') as f:
    json.dump(meta, f)

# %%
# !kaggle datasets create -p "/kaggle/working/Datasets" --dir-mode zip
# Out:
# Starting upload for file S14_MI.zip
# 100%|█████████████████████████████████████████| 357M/357M [00:03<00:00, 103MB/s]
# Upload successful: S14_MI.zip (357MB)
# Starting upload for file S14_ME.zip
# 100%|█████████████████████████████████████████| 358M/358M [00:02<00:00, 130MB/s]
# Upload successful: S14_ME.zip (358MB)
# Starting upload for file S12_MI.zip
# 100%|█████████████████████████████████████████| 382M/382M [00:02<00:00, 136MB/s]
# Upload successful: S12_MI.zip (382MB)
# Starting upload for file S09_ME.zip
# 100%|█████████████████████████████████████████| 363M/363M [00:02<00:00, 145MB/s]
# Upload successful: S09_ME.zip (363MB)
# Starting upload for file S09_MI.zip
# 100%|█████████████████████████████████████████| 373M/373M [00:02<00:00, 141MB/s]
# Upload successful: S09_MI.zip (373MB)
# Starting upload for file S02_MI.zip
# 100%|█████████████████████████████████████████| 360M/360M [00:02<00:00, 147MB/s]
# Upload successful: S02_MI.zip (360MB)
# ...
